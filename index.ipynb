# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Scrape events from a website
# * Follow links to those events to retrieve further information
# * Clean and store scraped data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
#Load the https://www.residentadvisor.net/events page in your browser.

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
#Open the inspect element feature in your browser

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
from bs4 import BeautifulSoup
import requests

# %%
import pandas as pd

def scrape_events(events_page_url):
    #Your code here
    html_page = requests.get(events_page_url)
    soup = BeautifulSoup(html_page.content, 'html.parser')
    container = soup.find('div', class_='fl col4')
    events_container = container.findAll('article')
    length = len(events_container)
    
    names = []
    venues = []
    dates = []
    attendees = []
    
    for i in range(0, length):
        
        name = events_container[i].find('h1').find('a').text
        names.append(name)
        
        venue = events_container[i].find('h1').find('span').text
        venues.append(venue)
        
        date = events_container[i].find('time').attrs['datetime']
        date = date[0:10]
        dates.append(date)
        
        for i in range(0, length):    
            attendee = events_container[i].find('p', class_='attending')
            if attendee == None:
                attendee = 0
            else:
                attendee = int(events_container[i].find('p', class_='attending').find('span').text)
            attendees.append(attendee)
 
    df = pd.DataFrame([names, venues, dates, attendees]).transpose()
    df.dropna(how='any', inplace=True)
    df.columns = ['Event_Name', 'Venue', 'Date', 'Number_Attending']
    
        
    return df
    
    
scrape_events('https://www.residentadvisor.net/events')
# Out:
#                                             Event_Name  \
# 0    Paradox with Rapha, Davide Del Vecchio, Alison...
# 1                                Defected Croatia 2019
# 2                              Umami Salame Afterhours
# 3                          Sneak Every Tuesday at Xoyo
# 4                                    Black Milk (Live)
# 5    Final Cut: Midweek Party - R&B, Charts, House ...
# 6                               Glory To Sound: Sophie
# 7                                        Diggers Dozen
# 8                                     Mahiki Wednesday
# 9                           Wednesdays // £2.50 Drinks
# 10                                              Desire
# 11                            Harvey Sutherland (Live)
# 12   Warm Up - Live dj set at Sweet Harmony: Rave -...
# 13   Rhythm Section presents: Remi + Iyamah + Cosim...
# 14         Concrete Lates: Dego, GE-Ology, Ruby Savage
# 15                   Kings Cross Social Pres: Kidology
# 16     Jazz Plus presents: Elephant Talk and Vellichor
# 17   Bad Decisions Project X A-Level Results Night ...
# 18                              TND Ferragosto Special
# 19                                               SIREN
# 20                            Baile LDN with Leo Justi
# 21   celestite Summer: Felix Lee, Air Max '97, Céci...
# 22   Soul In Motion: Krust, DJ Lee, Phaction, IN:Mo...
# 23                                       Bring it Back
# 24                        TBT A-Level Results UV Party
# 25           A Level Results Party 2019 at Tiger Tiger
# 26                     Flamingo Pier Terrace Thursdays
# 27                         Planet Panama (Netil Radio)
# 28              Devil's Pie: D'Angelo Screening & Talk
# 29                            Harvey Sutherland (Live)
# ..                                                 ...
# 180  Sundays at fabric: Jacob Husley, Illi & Separa...
# 181  Rhythm Section presents Wax'o Paradiso Summer ...
# 182           Our House in Kingsland Road (Night Time)
# 183                 Slump Sounds presents: Summer Slam
# 184                                          Glamorous
# 185                          We Love Soul Roof Top BBQ
# 186  Glory To Sound: Riz La Teef, Al Wootton, Lee K...
# 187                             OSS: The Birthday Spot
# 188                   4 To The Floor presents Pete BBE
# 189                    Fat Daddy's Soul Food Day Party
# 190                        Rum & Wings - All Day Party
# 191               Mehmooni- A Persian Sunday Gathering
# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
from datetime import datetime
from datetime import timedelta

# %%
def next_page(url):
    #Your code here
    date = url[-10:]
    date_format = datetime.strptime(date, '%Y-%m-%d').date()
    next_date = date_format + timedelta(days=7)
    next_date_format = str(next_date)
    next_page_url = url[0:-10] + next_date_format   
    return next_page_url

# %%
next_page('https://www.residentadvisor.net/events/uk/london/week/2019-08-02')
# Out:
# 'https://www.residentadvisor.net/events/uk/london/week/2019-08-09'

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
#Your code here

def next_events(number, url):
    
    current_url = url
    count = 0
    grand_df = pd.DataFrame(columns=['Event_Name', 'Venue', 'Date', 'Number_Attending'])
    
    while count <= number:
        df = scrape_events(current_url)
        count += len(scrape_events(current_url))
        current_url = next_page(current_url)
        grand_df = pd.concat([grand_df, df])
    
    grand_df.reset_index(inplace=True)
    grand_df.drop('index', axis=1, inplace=True)

    return grand_df

# %%
next_events(1000, 'https://www.residentadvisor.net/events/uk/london/week/2019-08-19')
# Out:
#                                              Event_Name  \
# 0                                  Desire Magic Mondays
# 1             The Cause X London DJ School (DJ Lessons)
# 2                           Rum & Wings - All Day Party
# 3                      Play London Every Monday at Xoyo
# 4                                     Clear Soul Forces
# 5                       Point.// Sunday Daytime Outdoor
# 6           Bashment Meets Hiphop & Afrobeats Day Party
# 7                                         Kandy Mondays
# 8                      Paradox presents Tuesday Madness
# 9                   Umami Salame presents Saytek (Live)
# 10                          Sneak Every Tuesday at Xoyo
# 11                  The Jones Girls Feat. Shirley Jones
# 12    Artificial Hells #3 - Piksel//Lost Alter//More...
# 13    Final Cut: Midweek Party - R&B, Charts, House ...
# 14                           Wednesdays // £2.50 Drinks
# 15                                               Desire
# 16    Love Drums - Live dj set at Sweet Harmony: Rav...
# 17                                 mau5trap label party
# 18                       Dele Sosimi Afrobeat Orchestra
# 19                King Yellowman & The Sagittarius Band
# 20                                             Two's #2
# 21                      The F Lab presents Cosmic Flush
# 22       Face 2 Face x Tekno Disco Summer Rooftop Party
# 23                                                SIREN
# 24    TND feat. CASSIMM, Francesco Poggi, Fabiano Bi...
# 25                  Fresh Thursdays Bank Holiday Warmup
# 26                                        Bring it Back
# 27                          TBT - (Throwback Thursdays)
# 28                   Hip Hop Karaoke at Queen of Hoxton
# 29                                        Way Past Cool
# ...                                                 ...
# 1004                                       Shapeshifter
# 1005                                             Antics
# 1006                                           Novelist
# 1007                                Loscil Live AV Show
# 1008        Student Night Every Friday at Cafe de Paris
# 1009                                            Fridays
# 1010                      Fridays at PI // £2.50 Drinks
# 1011           Cogo presents Gorgon City & Sonny Fodera
# 1012  fabric XX: Seth Troxler, Marcel Dettmann & Fra...
# 1013        Pure Events presents - Jess Bays (Defected)
# 1014  Up On The Roof...After Dark with Alison Limeri...
# 1015  Eat Your Own Ears presents Jacques Greene (DJ ...
# 1016                                      Leroy Burgess
# 1017                       Deep Depth Goes Out Out pt 2
# 1018                                Fantasy FM's Fusion
# 1019                           Disco Shed with Deekline
# 1020         Spoony's House - Omeara, October 19th 2019
# 1021      Soul City: Disco, House & Soul Every Saturday
# 1022               Pleasurehood. Every Saturday at XOYO
# 1023                Crush: Hip Hop & RnB Every Saturday
# 1024                 Alessandro Cortini + Suzanne Ciani
